# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnyghosh108/assignment-1/blob/main/digital_image_processing_3rd_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread("/content/drive/MyDrive/Colab Notebooks/data/public/jadeja.jpg")

# %%
 cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=720x1280>

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=720x1280>
